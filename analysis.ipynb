# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
found_triangles = pd.read_csv("base_run/arbitrage.csv")
stats = pd.read_csv("base_run/stats_.csv")

# %%
sns.boxplot(stats,  y="duration", x="found")
# Out:
# <Axes: xlabel='found', ylabel='duration'>
